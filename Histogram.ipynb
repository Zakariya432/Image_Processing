# %%
pip install opencv-python #used for image processing
# Out:
# Requirement already satisfied: opencv-python in ./opt/anaconda3/lib/python3.9/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.0 in ./opt/anaconda3/lib/python3.9/site-packages (from opencv-python) (1.20.3)
# WARNING: Error parsing requirements for requests-oauthlib: [Errno 2] No such file or directory: '/Users/zakariyaahmed/opt/anaconda3/lib/python3.9/site-packages/requests_oauthlib-1.3.1.dist-info/METADATA'
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# Creating dataset
np.random.seed(23685752)
N_points = 10000
n_bins = 20

# Creating distribution
x = np.random.randn(N_points)
y = .8 ** x + np.random.randn(10000) + 25

# Creating histogram
fig, axs = plt.subplots(1, 1,
						figsize =(10, 7),
						tight_layout = True)

axs.hist(x, bins = n_bins)

# Show plot
plt.show()

# %%
import cv2
from skimage import io

img = io.imread("Hist1.jpeg")

from matplotlib import pyplot as plot

image = cv2.imread('Hist1.jpeg')

plot.hist(image.ravel(),256)
plot.show()

io.imshow(img)
